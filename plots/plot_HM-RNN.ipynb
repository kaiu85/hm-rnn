# %%
import numpy as np
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

# %matplotlib notebook

N = 100

x = np.loadtxt('log_HM_RNN_GERMAN11.txt')
y = np.loadtxt('log_HM_RNN_GERMAN12.txt')

print(x.shape)
print(y.shape)

plt.plot(x, label = '11')
plt.plot(y, label = '12')
#plt.ylim([100, 200])
plt.legend()
plt.show()
# Out:
# (22000,)
# (19836,)
# <img src="data:image/png;base64,..." width="640">
